# %%
import pandas as pd
pd.read_csv('C:\\Users\\George.Macharia\Downloads\\estimated_numbers.csv')
# Out:
#                                 Country  Year              No. of cases  \
# 0                           Afghanistan  2017     630308[495000-801000]
# 1                               Algeria  2017                         0
# 2                                Angola  2017  4615605[3106000-6661000]
# 3                             Argentina  2017                         0
# 4                               Armenia  2017                         0
# ..                                  ...   ...                       ...
# 851  Venezuela (Bolivarian Republic of)  2010        57257[47000-74000]
# 852                            Viet Nam  2010        23062[21000-26000]
# 853                               Yemen  2010   1134927[611000-2686000]
# 854                              Zambia  2010  2169307[1449000-3095000]
# 855                            Zimbabwe  2010   1095083[606000-1717000]
#
#          No. of deaths  No. of cases_median  No. of cases_min  \
# ...

# %%
import pandas as pd
pd.read_csv('C:\\Users\\George.Macharia\Downloads\\estimated_numbers.csv')
# Out:
#                                 Country  Year              No. of cases  \
# 0                           Afghanistan  2017     630308[495000-801000]
# 1                               Algeria  2017                         0
# 2                                Angola  2017  4615605[3106000-6661000]
# 3                             Argentina  2017                         0
# 4                               Armenia  2017                         0
# ..                                  ...   ...                       ...
# 851  Venezuela (Bolivarian Republic of)  2010        57257[47000-74000]
# 852                            Viet Nam  2010        23062[21000-26000]
# 853                               Yemen  2010   1134927[611000-2686000]
# 854                              Zambia  2010  2169307[1449000-3095000]
# 855                            Zimbabwe  2010   1095083[606000-1717000]
#
#          No. of deaths  No. of cases_median  No. of cases_min  \
# ...

# %%
import pandas as pd
data_frame=pd.read_csv('C:\\Users\\George.Macharia\Downloads\\estimated_numbers.csv')
data_frame.shape
# Out:
# (856, 11)

# %%
import pandas as pd
data_frame=pd.read_csv('C:\\Users\\George.Macharia\Downloads\\estimated_numbers.csv')
data_frame.describe
# Out:
# <bound method NDFrame.describe of                                 Country  Year              No. of cases  \
# 0                           Afghanistan  2017     630308[495000-801000]
# 1                               Algeria  2017                         0
# 2                                Angola  2017  4615605[3106000-6661000]
# 3                             Argentina  2017                         0
# 4                               Armenia  2017                         0
# ..                                  ...   ...                       ...
# 851  Venezuela (Bolivarian Republic of)  2010        57257[47000-74000]
# 852                            Viet Nam  2010        23062[21000-26000]
# 853                               Yemen  2010   1134927[611000-2686000]
# 854                              Zambia  2010  2169307[1449000-3095000]
# 855                            Zimbabwe  2010   1095083[606000-1717000]
#
#          No. of deaths  No. of cases_median  No. of cases_min  \
# ...

# %%
data_frame.values
# Out:
# array([['Afghanistan', 2017, '630308[495000-801000]', ..., 110.0, 510.0,
#         'Eastern Mediterranean'],
#        ['Algeria', 2017, '0', ..., nan, nan, 'Africa'],
#        ['Angola', 2017, '4615605[3106000-6661000]', ..., 9970.0, 16600.0,
#         'Africa'],
#        ...,
#        ['Yemen', 2010, '1134927[611000-2686000]', ..., 90.0, 8490.0,
#         'Eastern Mediterranean'],
#        ['Zambia', 2010, '2169307[1449000-3095000]', ..., 5580.0, 7510.0,
#         'Africa'],
#        ['Zimbabwe', 2010, '1095083[606000-1717000]', ..., 80.0, 6190.0,
#         'Africa']], dtype=object)

# %%
data_frame["age"].hist()
